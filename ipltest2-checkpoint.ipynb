# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Prashanth Yerabati\\Python Lab'

# %%
import pandas as pd
import numpy as np

# %%
ipl = pd.read_csv("matches2008-2016_1.csv")
ipl_new = pd.read_csv("matches2017_1.csv")

# %%
matches = ipl.append(ipl_new, ignore_index = True)

# %%
matches.shape
# Out:
# (636, 19)

# %%
matches.info
# Out:
# <bound method DataFrame.info of     match_id  season        city        date team1_id team2_id toss_winner  \
# 0     2008_1  2008.0   Bangalore  18-04-2008      KKR      RCB         RCB
# 1     2008_2  2008.0  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2     2008_3  2008.0       Delhi  19-04-2008       RR       DD          RR
# 3     2008_4  2008.0      Mumbai  20-04-2008       MI      RCB          MI
# 4     2008_5     NaN     Kolkata  20-04-2008       DC      KKR          DC
# 5     2008_6  2008.0      Jaipur  21-04-2008      KXI       RR         KXI
# 6     2008_7  2008.0   Hyderabad  22-04-2008       DC       DD          DC
# 7     2008_8  2008.0     Chennai  23-04-2008      CSK       MI          MI
# 8     2008_9  2008.0   Hyderabad  24-04-2008       DC       RR          RR
# 9    2008_10     NaN  Chandigarh  25-04-2008      KXI       MI          MI
# 10   2008_11  2008.0   Bangalore  26-04-2008      RCB       RR          RR
# ...

# %%
matches.dtypes
# Out:
# match_id               object
# season                float64
# city                   object
# date                   object
# team1_id               object
# team2_id               object
# toss_winner            object
# toss_decision          object
# result                 object
# dl_applied              int64
# winner                 object
# win_by_runs             int64
# win_by_wickets          int64
# player_of_match        object
# player_of_match_id    float64
# venue                  object
# venue_id                int64
# umpire1                object
# umpire2                object
# dtype: object

# %%
matches.head(6)
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 19 columns):
# match_id              636 non-null object
# season                634 non-null float64
# city                  629 non-null object
# date                  636 non-null object
# team1_id              636 non-null object
# team2_id              636 non-null object
# toss_winner           636 non-null object
# toss_decision         636 non-null object
# result                636 non-null object
# dl_applied            636 non-null int64
# winner                633 non-null object
# win_by_runs           636 non-null int64
# win_by_wickets        636 non-null int64
# player_of_match       633 non-null object
# player_of_match_id    629 non-null float64
# venue                 636 non-null object
# venue_id              636 non-null int64
# umpire1               635 non-null object
# umpire2               635 non-null object
# dtypes: float64(2), int64(4), object(13)
# ...

# %%
matches[['city','date','team1_id','team2_id','toss_winner','toss_decision','result','winner','player_of_match','venue','venue_id','umpire1','umpire2']] = \
    matches[['city','date','team1_id','team2_id','toss_winner','toss_decision','result','winner','player_of_match','venue','venue_id','umpire1','umpire2']].astype('category')

# %%
matches.dtypes
# Out:
# match_id                object
# season                 float64
# city                  category
# date                  category
# team1_id              category
# team2_id              category
# toss_winner           category
# toss_decision         category
# result                category
# dl_applied               int64
# winner                category
# win_by_runs              int64
# win_by_wickets           int64
# player_of_match       category
# player_of_match_id     float64
# venue                 category
# venue_id              category
# umpire1               category
# umpire2               category
# dtype: object

# %%
matches['match_id'] = matches['match_id'].astype('category')

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 19 columns):
# match_id              636 non-null category
# season                634 non-null float64
# city                  629 non-null category
# date                  636 non-null category
# team1_id              636 non-null category
# team2_id              636 non-null category
# toss_winner           636 non-null category
# toss_decision         636 non-null category
# result                636 non-null category
# dl_applied            636 non-null int64
# winner                633 non-null category
# win_by_runs           636 non-null int64
# win_by_wickets        636 non-null int64
# player_of_match       633 non-null category
# player_of_match_id    629 non-null float64
# venue                 636 non-null category
# venue_id              636 non-null category
# umpire1               635 non-null category
# umpire2               635 non-null category
# ...

# %%
matches.describe()
# Out:
#             season  dl_applied  win_by_runs  win_by_wickets  \
# count   634.000000  636.000000   636.000000      636.000000
# mean   2012.504732    0.025157    13.682390        3.372642
# std       2.765874    0.156726    23.908877        3.420338
# min    2008.000000    0.000000     0.000000        0.000000
# 25%    2010.000000    0.000000     0.000000        0.000000
# 50%    2012.000000    0.000000     0.000000        4.000000
# 75%    2015.000000    0.000000    20.000000        7.000000
# max    2017.000000    1.000000   146.000000       10.000000
#
#        player_of_match_id
# count          629.000000
# mean           210.872814
# std            180.138057
# min              1.000000
# 25%             69.000000
# 50%            149.000000
# 75%            321.000000
# max            691.000000

# %%
matches.venue_id.value_counts()
# Out:
# 7     66
# 3     61
# 2     60
# 1     57
# 4     49
# 5     48
# 9     46
# 6     33
# 26    17
# 10    17
# 32    15
# 13    15
# 14    12
# 20    12
# 19    11
# 25    11
# 33    10
# 23     9
# 16     8
# 28     7
# 29     7
# 21     7
# 12     7
# 11     7
# 31     7
# 30     6
# 27     6
# 8      5
# 24     5
# 34     4
# 15     3
# 22     3
# 17     3
# 18     2
# Name: venue_id, dtype: int64

# %%
matches.isna().sum()
# Out:
# match_id              0
# season                2
# city                  7
# date                  0
# team1_id              0
# team2_id              0
# toss_winner           0
# toss_decision         0
# result                0
# dl_applied            0
# winner                3
# win_by_runs           0
# win_by_wickets        0
# player_of_match       3
# player_of_match_id    7
# venue                 0
# venue_id              0
# umpire1               1
# umpire2               1
# dtype: int64

# %%
matches.isnull().sum()
# Out:
# match_id              0
# season                2
# city                  7
# date                  0
# team1_id              0
# team2_id              0
# toss_winner           0
# toss_decision         0
# result                0
# dl_applied            0
# winner                3
# win_by_runs           0
# win_by_wickets        0
# player_of_match       3
# player_of_match_id    7
# venue                 0
# venue_id              0
# umpire1               1
# umpire2               1
# dtype: int64

# %%
matches.shape
# Out:
# (636, 19)

# %%
matches.iloc[:,1:19] = matches.iloc[:,1:20].replace('',np.nan)

# %%
matches[404:410]
# Out:
#     match_id  season       city        date team1_id team2_id toss_winner  \
# 404   2014_7  2014.0    Sharjah  20-04-2014       RR      KXI         KXI
# 405   2014_8  2014.0  Abu Dhabi  21-04-2014      CSK       DD         CSK
# 406   2014_9  2014.0    Sharjah  22-04-2014      KXI      SRH         SRH
# 407  2014_10  2014.0        NaN  23-04-2014      CSK       RR          RR
# 408  2014_11  2014.0    Sharjah  24-04-2014      KKR      RCB         RCB
# 409  2014_12  2014.0        NaN  25-04-2014      SRH       DD         SRH
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 404         field  normal           0    KXI            0               7
# 405           bat  normal           0    CSK           93               0
# 406         field  normal           0    KXI           72               0
# 407         field  normal           0    CSK            7               0
# 408         field  normal           0    KKR            2               0
# ...

# %%
matches_na_rows_dropped = matches.copy()

# %%
matches_na_rows_dropped = matches_na_rows_dropped.dropna(axis=0)

# %%
matches.shape
matches_na_rows_dropped.shape
# Out:
# (619, 19)

# %%
matches.shape
# Out:
# (636, 19)

# %%
matches_na_cols_dropped  = matches.copy()

# %%
mathces_na_cols_dropped = matches_na_cols_dropped.dropna(axis=1)

# %%
mathces_na_cols_dropped.shape
# Out:
# (636, 12)

# %%
from sklearn.preprocessing import Imputer

# %%
mean_imputer = Imputer(strategy = "mean")

# %%
mean_imputed = matches.copy()

# %%
mean_imputed.dtypes
# Out:
# match_id              category
# season                 float64
# city                  category
# date                  category
# team1_id              category
# team2_id              category
# toss_winner           category
# toss_decision         category
# result                category
# dl_applied               int64
# winner                category
# win_by_runs              int64
# win_by_wickets           int64
# player_of_match       category
# player_of_match_id     float64
# venue                 category
# venue_id              category
# umpire1               category
# umpire2               category
# dtype: object

# %%
mean_imputed.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]] = mean_imputer.fit_transform(mean_imputed.mean_imputed.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]])

# %%
mean_imputed.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]].isna().sum()
# Out:
# season                0
# dl_applied            0
# win_by_runs           0
# win_by_wickets        0
# player_of_match_id    0
# dtype: int64

# %%
mean_imputed.shape
# Out:
# (636, 19)

# %%
mean_imputed.head(6)
# Out:
#   match_id       season        city        date team1_id team2_id toss_winner  \
# 0   2008_1  2008.000000   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2  2008.000000  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3  2008.000000       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4  2008.000000      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5  2012.504732     Kolkata  20-04-2008       DC      KKR          DC
# 5   2008_6  2008.000000      Jaipur  21-04-2008      KXI       RR         KXI
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal         0.0    KKR        140.0             0.0
# 1           bat  normal         0.0    CSK         33.0             0.0
# 2           bat  normal         0.0     DD          0.0             9.0
# 3           bat  normal         0.0    RCB          0.0             5.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
range_scaler = MinMaxScaler()

# %%
range_scaled = mean_imputed.copy()

# %%
range_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]] = range_scaler.fit_transform(range_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]])

# %%
range_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]].isna().sum()
# Out:
# season                0
# dl_applied            0
# win_by_runs           0
# win_by_wickets        0
# player_of_match_id    0
# dtype: int64

# %%
range_scaled.head(6)
# Out:
#   match_id    season        city        date team1_id team2_id toss_winner  \
# 0   2008_1  0.000000   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2  0.000000  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3  0.000000       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4  0.000000      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5  0.500526     Kolkata  20-04-2008       DC      KKR          DC
# 5   2008_6  0.000000      Jaipur  21-04-2008      KXI       RR         KXI
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal         0.0    KKR     0.958904             0.0
# 1           bat  normal         0.0    CSK     0.226027             0.0
# 2           bat  normal         0.0     DD     0.000000             0.9
# 3           bat  normal         0.0    RCB     0.000000             0.5
# 4           bat  normal         0.0    KKR     0.000000             0.5
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
standard_scaled = mean_imputed.copy()

# %%
standard_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]] = standard_scaler.fit_transform(standard_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]])

# %%
standard_scaled.loc[:,["season","dl_applied","win_by_runs","win_by_wickets","player_of_match_id"]].isna().sum()
# Out:
# season                0
# dl_applied            0
# win_by_runs           0
# win_by_wickets        0
# player_of_match_id    0
# dtype: int64

# %%
standard_scaled.head(6)
# Out:
#   match_id    season        city        date team1_id team2_id toss_winner  \
# 0   2008_1 -1.632538   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2 -1.632538  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3 -1.632538       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4 -1.632538      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5  0.000000     Kolkata  20-04-2008       DC      KKR          DC
# 5   2008_6 -1.632538      Jaipur  21-04-2008      KXI       RR         KXI
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal   -0.160644    KKR     5.287452       -0.986831
# 1           bat  normal   -0.160644    CSK     0.808604       -0.986831
# 2           bat  normal   -0.160644     DD    -0.572723        1.646559
# 3           bat  normal   -0.160644    RCB    -0.572723        0.476163
# 4           bat  normal   -0.160644    KKR    -0.572723        0.476163
# ...
