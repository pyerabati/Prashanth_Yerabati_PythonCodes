# %%
import pandas as pd

# %%
ipl=pd.read_csv('matches2008-2016.csv')
ipl_new=pd.read_csv('matches2017.csv')

# %%
ipl.head(2)
ipl_new.head(2)
# Out:
#   match_id  season       city        date team1_id team2_id toss_winner  \
# 0   2017_1    2017  Hyderabad  05-04-2017      SRH      RCB         RCB
# 1   2017_2    2017       Pune  06-04-2017       MI      RPS         RPS
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    SRH           35               0
# 1         field  normal           0    RPS            0               7
#
#   player_of_match  player_of_match_id  \
# 0    Yuvraj Singh                  88
# 1    Steven Smith                 321
#
#                                            venue  venue_id         umpire1  \
# 0  Rajiv Gandhi International Stadium, Hyderabad         4     AY Dandekar
# 1        Maharashtra Cricket Association Stadium        32  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %%
ipl_final = ipl.append(ipl_new,ignore_index=True)

# %%
ipl_final.head(2)
ipl_final.tail(2)
ipl_new.shape
ipl.shape
# Out:
# (577, 19)

# %%
ipl_final=ipl_final.set_index("match_id")

# %%
ipl_final.iloc[0:2,0:2]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
ipl_final.loc[["2008_1","2008_2"],["season","city"]]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
ipl_final.loc[ipl_final.index[0:2],["season","city"]]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
ipl_final.loc[["2008_1","2008_2"],ipl_final.columns[0:2]]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
import pandas as pd
import numpy as np

# %%
labels = ['Pregnant', "Glucose", "BloddPressure","SkinThickness","Insulin","BMI","DiabetsPedigreeFunction","Age","Outcome"]

# %%
diabetes = pd.read_csv("pima_indians_diabetes.csv",names=labels)

# %%
diabetes.head(2)
diabetes.tail(2)
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.dtypes
# Out:
# Pregnant                     int64
# Glucose                      int64
# BloddPressure                int64
# SkinThickness                int64
# Insulin                      int64
# BMI                        float64
# DiabetsPedigreeFunction    float64
# Age                          int64
# Outcome                      int64
# dtype: object

# %%
diabetes.Pregnant = diabetes.Pregnant.astype("category")

# %%
diabetes.dtypes
# Out:
# Pregnant                   category
# Glucose                       int64
# BloddPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetsPedigreeFunction     float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
diabetes.Outcome = diabetes.Outcome.astype("category")

# %%
diabetes.dtypes
# Out:
# Pregnant                   category
# Glucose                       int64
# BloddPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetsPedigreeFunction     float64
# Age                           int64
# Outcome                    category
# dtype: object

# %%
diabetes.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnant                   768 non-null category
# Glucose                    768 non-null int64
# BloddPressure              768 non-null int64
# SkinThickness              768 non-null int64
# Insulin                    768 non-null int64
# BMI                        768 non-null float64
# DiabetsPedigreeFunction    768 non-null float64
# Age                        768 non-null int64
# Outcome                    768 non-null category
# dtypes: category(2), float64(2), int64(5)
# memory usage: 44.4 KB

# %%
diabetes.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
diabetes.Pregnant.value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnant, dtype: int64

# %%
diabetes.isnull().sum()
# Out:
# Pregnant                     0
# Glucose                      5
# BloddPressure               35
# SkinThickness              227
# Insulin                    374
# BMI                         11
# DiabetsPedigreeFunction      0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
diabetes.head(6)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0        6    148.0           72.0           35.0      NaN  33.6
# 1        1     85.0           66.0           29.0      NaN  26.6
# 2        8    183.0           64.0            NaN      NaN  23.3
# 3        1     89.0           66.0           23.0     94.0  28.1
# 4        0    137.0           40.0           35.0    168.0  43.1
# 5        5    116.0           74.0            NaN      NaN  25.6
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1
# 5                    0.201   30       0

# %%
diabetes.iloc[:,1:8]
# Out:
#      Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0      148.0           72.0           35.0      NaN  33.6
# 1       85.0           66.0           29.0      NaN  26.6
# 2      183.0           64.0            NaN      NaN  23.3
# 3       89.0           66.0           23.0     94.0  28.1
# 4      137.0           40.0           35.0    168.0  43.1
# 5      116.0           74.0            NaN      NaN  25.6
# 6       78.0           50.0           32.0     88.0  31.0
# 7      115.0            NaN            NaN      NaN  35.3
# 8      197.0           70.0           45.0    543.0  30.5
# 9      125.0           96.0            NaN      NaN   NaN
# 10     110.0           92.0            NaN      NaN  37.6
# 11     168.0           74.0            NaN      NaN  38.0
# 12     139.0           80.0            NaN      NaN  27.1
# 13     189.0           60.0           23.0    846.0  30.1
# 14     166.0           72.0           19.0    175.0  25.8
# ...

# %%
diabetes.iloc[:,1:8] = diabetes.iloc[:,1:8].replace(0,np.nan)

# %%
diabetes.head(6)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0        6    148.0           72.0           35.0      NaN  33.6
# 1        1     85.0           66.0           29.0      NaN  26.6
# 2        8    183.0           64.0            NaN      NaN  23.3
# 3        1     89.0           66.0           23.0     94.0  28.1
# 4        0    137.0           40.0           35.0    168.0  43.1
# 5        5    116.0           74.0            NaN      NaN  25.6
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1
# 5                    0.201   30       0

# %%
diabetes_na_rows_dropped = diabetes.copy()

# %%
diabetes_na_rows_dropped = diabetes_na_rows_dropped.dropna(axis=0)

# %%
diabetes_na_rows_dropped.shape
# Out:
# (392, 9)

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes_na_cols_dropped = diabetes.copy()

# %%
diabetes_na_cols_dropped = diabetes_na_cols_dropped.dropna(axis=1)

# %%
diabetes_na_cols_dropped.shape
# Out:
# (768, 4)

# %%
from sklearn.preprocessing import Imputer

# %%
mean_imputer = Imputer(strategy="mean")

# %%
diabetes.isnull().sum()
# Out:
# Pregnant                     0
# Glucose                      5
# BloddPressure               35
# SkinThickness              227
# Insulin                    374
# BMI                         11
# DiabetsPedigreeFunction      0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
mean_imputed = diabetes.copy()

# %%
mean_imputed.iloc[:,1:6] = mean_imputer.fit_transform(mean_imputed.iloc[:,1:6])

# %%
mean_imputed.isna().sum()
# Out:
# Pregnant                   0
# Glucose                    0
# BloddPressure              0
# SkinThickness              0
# Insulin                    0
# BMI                        0
# DiabetsPedigreeFunction    0
# Age                        0
# Outcome                    0
# dtype: int64

# %%
mean_imputed.head(6)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness     Insulin   BMI  \
# 0        6    148.0           72.0       35.00000  155.548223  33.6
# 1        1     85.0           66.0       29.00000  155.548223  26.6
# 2        8    183.0           64.0       29.15342  155.548223  23.3
# 3        1     89.0           66.0       23.00000   94.000000  28.1
# 4        0    137.0           40.0       35.00000  168.000000  43.1
# 5        5    116.0           74.0       29.15342  155.548223  25.6
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1
# 5                    0.201   30       0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
range_scaler = MinMaxScaler()

# %%
range_scaled = mean_imputed.copy()

# %%
range_scaled.iloc[:,1:8]= range_scaler.fit_transform(range_scaled.iloc[:,1:8])

# %%
range_scaled.describe()
# Out:
#           Glucose  BloddPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean     0.501205       0.493930       0.240798    0.170130    0.291564
# std      0.196361       0.123432       0.095554    0.102189    0.140596
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%      0.359677       0.408163       0.195652    0.129207    0.190184
# 50%      0.470968       0.491863       0.240798    0.170130    0.290389
# 75%      0.620968       0.571429       0.271739    0.170130    0.376278
# max      1.000000       1.000000       1.000000    1.000000    1.000000
#
#        DiabetsPedigreeFunction         Age
# count               768.000000  768.000000
# mean                  0.168179    0.204015
# std                   0.141473    0.196004
# min                   0.000000    0.000000
# 25%                   0.070773    0.050000
# 50%                   0.125747    0.133333
# ...

# %%
range_scaled.head(6)
# Out:
#   Pregnant   Glucose  BloddPressure  SkinThickness   Insulin       BMI  \
# 0        6  0.670968       0.489796       0.304348  0.170130  0.314928
# 1        1  0.264516       0.428571       0.239130  0.170130  0.171779
# 2        8  0.896774       0.408163       0.240798  0.170130  0.104294
# 3        1  0.290323       0.428571       0.173913  0.096154  0.202454
# 4        0  0.600000       0.163265       0.304348  0.185096  0.509202
# 5        5  0.464516       0.510204       0.240798  0.170130  0.151329
#
#    DiabetsPedigreeFunction       Age Outcome
# 0                 0.234415  0.483333       1
# 1                 0.116567  0.166667       0
# 2                 0.253629  0.183333       1
# 3                 0.038002  0.000000       0
# 4                 0.943638  0.200000       1
# 5                 0.052519  0.150000       0

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
standard_scaled = mean_imputed.copy()

# %%
standard_scaled.iloc[:,1:8] = standard_scaler.fit_transform(standard_scaled.iloc[:,1:8])

# %%
standard_scaled.describe()
# Out:
#             Glucose  BloddPressure  SkinThickness       Insulin           BMI  \
# count  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02  7.680000e+02
# mean  -3.301757e-16   6.966722e-16   6.866252e-16 -2.352033e-16  3.553292e-16
# std    1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00  1.000652e+00
# min   -2.554131e+00  -4.004245e+00  -2.521670e+00 -1.665945e+00 -2.075119e+00
# 25%   -7.212214e-01  -6.953060e-01  -4.727737e-01 -4.007289e-01 -7.215397e-01
# 50%   -1.540881e-01  -1.675912e-02   8.087936e-16 -3.345079e-16 -8.363615e-03
# 75%    6.103090e-01   6.282695e-01   3.240194e-01 -3.345079e-16  6.029301e-01
# max    2.541850e+00   4.102655e+00   7.950467e+00  8.126238e+00  5.042087e+00
#
#        DiabetsPedigreeFunction           Age
# count             7.680000e+02  7.680000e+02
# mean              2.398978e-16  1.857600e-16
# std               1.000652e+00  1.000652e+00
# min              -1.189553e+00 -1.041549e+00
# ...
