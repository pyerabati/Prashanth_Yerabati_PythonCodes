# %%
import pandas as pd

# %%
ipl = pd.read_csv('matches2008-2016.csv')
ipl_new = pd.read_csv('matches2017.csv')

# %%
ipl.head(2)
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# 1    Michael Hussey                18.0
#
#                                                venue  venue_id    umpire1  \
# 0         M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
# 1  I.S. Bindra Punjab Cricket Association Stadium...         9  MR Benson
#
#        umpire2
# 0  RE Koertzen
# 1   SL Shastri

# %%
ipl_final = ipl.append(ipl_new,ignore_index=True)

# %%
ipl_final.tail(2)
# Out:
#     match_id  season       city        date team1_id team2_id toss_winner  \
# 634  2017_58    2017  Bangalore  19-05-2017      KKR       MI          MI
# 635  2017_59    2017  Hyderabad  21-05-2017       MI      RPS          MI
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 634         field  normal           0     MI            0               6
# 635           bat  normal           0     MI            1               0
#
#     player_of_match  player_of_match_id  \
# 634     Karn Sharma               254.0
# 635   Krunal Pandya               582.0
#
#                                              venue  venue_id   umpire1  \
# 634     M.Chinnaswamy Stadium Bengaluru, Karnataka         7  NJ Llong
# 635  Rajiv Gandhi International Stadium, Hyderabad         4  NJ Llong
#
#          umpire2
# 634  Nitin Menon
# 635       S Ravi

# %%
ipl_final=ipl_final.set_index("match_id")

# %%
# rwo number, column, number->iloc
ipl_final.iloc[0:2,0:2]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
# row name, columan name-> loc
ipl_final.loc[["2008_1","2008_2"],["season","city"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b875b308d6f9> in <module>()
#       1 # row name, columan name-> loc
# ----> 2 ipl_final.loc[["2008_1","2008_2"],["season","city"]]
#
# NameError: name 'ipl_final' is not defined

# %%
## row numbers,columna numbers->loc[index]
ipl_final.loc[ipl_final.index[0:2],["season","city"]]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
## row names,column numbers-> loc[,.columns[]]--> Location(LOC) - if any of them is string
## iloc - if both of them or represented through numbers
                                                    

ipl_final.loc[["2008_1","2008_2"],ipl_final.columns[0:2]]
# Out:
#           season        city
# match_id
# 2008_1      2008   Bangalore
# 2008_2      2008  Chandigarh

# %%
import pandas as pd
import numpy as np

# %%
labels = ['Pregnant', "Glucose", "BloddPressure","SkinThickness","Insulin","BMI","DiabetsPedigreeFunction","Age","Outcome"]

# %%
diabets = pd.read_csv("pima_indians_diabetes.csv",names=labels)

# %%
diabets.head(1)
# Out:
#    Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0         6      148             72             35        0  33.6
#
#    DiabetsPedigreeFunction  Age  Outcome
# 0                    0.627   50        1

# %%
diabets.dtypes
# Out:
# Pregnant                     int64
# Glucose                      int64
# BloddPressure                int64
# SkinThickness                int64
# Insulin                      int64
# BMI                        float64
# DiabetsPedigreeFunction    float64
# Age                          int64
# Outcome                      int64
# dtype: object

# %%
diabets.head(5)
# Out:
#    Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0         6      148             72             35        0  33.6
# 1         1       85             66             29        0  26.6
# 2         8      183             64              0        0  23.3
# 3         1       89             66             23       94  28.1
# 4         0      137             40             35      168  43.1
#
#    DiabetsPedigreeFunction  Age  Outcome
# 0                    0.627   50        1
# 1                    0.351   31        0
# 2                    0.672   32        1
# 3                    0.167   21        0
# 4                    2.288   33        1

# %%
diabets.Pregnant = diabets.Pregnant.astype("category")

# %%
diabets.dtypes
# Out:
# Pregnant                   category
# Glucose                       int64
# BloddPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetsPedigreeFunction     float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Convert the True Non integers to Categorical
diabets.Outcome = diabets.Outcome.astype("category")

# %%
    diabetes.dtypes
# Out:
# Pregnant                   category
# Glucose                       int64
# BloddPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetsPedigreeFunction     float64
# Age                           int64
# Outcome                    category
# dtype: object

# %%
# Find the statistics summary for Integer columns to understand the data and find outliers
diabets.describe()
# Out:
#           Glucose  BloddPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean   120.894531      69.105469      20.536458   79.799479   31.992578
# std     31.972618      19.355807      15.952218  115.244002    7.884160
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%     99.000000      62.000000       0.000000    0.000000   27.300000
# 50%    117.000000      72.000000      23.000000   30.500000   32.000000
# 75%    140.250000      80.000000      32.000000  127.250000   36.600000
# max    199.000000     122.000000      99.000000  846.000000   67.100000
#
#        DiabetsPedigreeFunction         Age
# count               768.000000  768.000000
# mean                  0.471876   33.240885
# std                   0.331329   11.760232
# min                   0.078000   21.000000
# 25%                   0.243750   24.000000
# 50%                   0.372500   29.000000
# ...

# %%
diabets.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# Categorial Values Distribution
diabets.Pregnant.value_counts()
# Out:
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnant, dtype: int64

# %%
## Identifying Missing Values
diabets.isnull().sum()
# Out:
# Pregnant                   0
# Glucose                    0
# BloddPressure              0
# SkinThickness              0
# Insulin                    0
# BMI                        0
# DiabetsPedigreeFunction    0
# Age                        0
# Outcome                    0
# dtype: int64

# %%
## Some time Missing values represtned with Zero value instead actual measure Identify those
diabets.head(6)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0        6      148             72             35        0  33.6
# 1        1       85             66             29        0  26.6
# 2        8      183             64              0        0  23.3
# 3        1       89             66             23       94  28.1
# 4        0      137             40             35      168  43.1
# 5        5      116             74              0        0  25.6
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1
# 5                    0.201   30       0

# %%
diabets.iloc[:,1:8]
# Out:
#      Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# 5        116             74              0        0  25.6
# 6         78             50             32       88  31.0
# 7        115              0              0        0  35.3
# 8        197             70             45      543  30.5
# 9        125             96              0        0   0.0
# 10       110             92              0        0  37.6
# 11       168             74              0        0  38.0
# 12       139             80              0        0  27.1
# 13       189             60             23      846  30.1
# 14       166             72             19      175  25.8
# ...

# %%
# Replace Missing values(values with zeros) with Nummpy.NAN
diabets.iloc[:,1:8] = diabets.iloc[:,1:8].replace(0,np.nan)

# %%
# Check wither they replaced or not
diabets.isna().sum()
# Out:
# Pregnant                     0
# Glucose                      5
# BloddPressure               35
# SkinThickness              227
# Insulin                    374
# BMI                         11
# DiabetsPedigreeFunction      0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
diabets.head(6)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness  Insulin   BMI  \
# 0        6    148.0           72.0           35.0      NaN  33.6
# 1        1     85.0           66.0           29.0      NaN  26.6
# 2        8    183.0           64.0            NaN      NaN  23.3
# 3        1     89.0           66.0           23.0     94.0  28.1
# 4        0    137.0           40.0           35.0    168.0  43.1
# 5        5    116.0           74.0            NaN      NaN  25.6
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1
# 5                    0.201   30       0

# %%
# Take the back up diabets dataset before we drop the missing value rows(Values with nan)
diabets_na_cols_dropped.dropna(axis=1)

# %%
# Drop the missing value rows from backup(for Rows Axis-0 in python, 1 in "R")
diabets_na_rows_dropped = diabets_na_rows_dropped.dropna(axis=0)

# %%
print(diabets.shape)
print(diabets_na_rows_dropped.shape)
# Out:
# (768, 9)
# (392, 9)

# %%
# Take the backup diabets dataset before we drop the missing values columns
diabets_na_cols_dropped = diabets.copy()

# %%
# Drop the missing value rows from backup(for Columns Axis-1 in python, 2 in "R"
diabets_na_cols_dropped = diabets_na_cols_dropped.dropna(axis=1)

# %% [raw]
# print(diabets.shape)
# print(diabets_na_cols_dropped.shape)

# %%
# Impute
from sklearn.preprocessing import Imputer

# %%
mean_imputer = Imputer(strategy="mean")

# %%
diabets.isnull().sum()
# Out:
# Pregnant                     0
# Glucose                      5
# BloddPressure               35
# SkinThickness              227
# Insulin                    374
# BMI                         11
# DiabetsPedigreeFunction      0
# Age                          0
# Outcome                      0
# dtype: int64

# %%
mean_imputed = diabets.copy()

# %%
mean_imputed.iloc[:,1:6] = mean_imputer.fit_transform(mean_imputed.iloc[:,1:6])

# %%
mean_imputed.isna().sum()
# Out:
# Pregnant                   0
# Glucose                    0
# BloddPressure              0
# SkinThickness              0
# Insulin                    0
# BMI                        0
# DiabetsPedigreeFunction    0
# Age                        0
# Outcome                    0
# dtype: int64

# %%
mean_imputed.head(5)
# Out:
#   Pregnant  Glucose  BloddPressure  SkinThickness     Insulin   BMI  \
# 0        6    148.0           72.0       35.00000  155.548223  33.6
# 1        1     85.0           66.0       29.00000  155.548223  26.6
# 2        8    183.0           64.0       29.15342  155.548223  23.3
# 3        1     89.0           66.0       23.00000   94.000000  28.1
# 4        0    137.0           40.0       35.00000  168.000000  43.1
#
#    DiabetsPedigreeFunction  Age Outcome
# 0                    0.627   50       1
# 1                    0.351   31       0
# 2                    0.672   32       1
# 3                    0.167   21       0
# 4                    2.288   33       1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
range_scaler = MinMaxScaler()

# %%
range_scaled = mean_imputed.copy()

# %%
range_scaled.iloc[:,1:8] = range_scaler.fit_transform(range_scaled.iloc[:,1:8])

# %%
range_scaled.describe()
# Out:
#           Glucose  BloddPressure  SkinThickness     Insulin         BMI  \
# count  768.000000     768.000000     768.000000  768.000000  768.000000
# mean     0.501205       0.493930       0.240798    0.170130    0.291564
# std      0.196361       0.123432       0.095554    0.102189    0.140596
# min      0.000000       0.000000       0.000000    0.000000    0.000000
# 25%      0.359677       0.408163       0.195652    0.129207    0.190184
# 50%      0.470968       0.491863       0.240798    0.170130    0.290389
# 75%      0.620968       0.571429       0.271739    0.170130    0.376278
# max      1.000000       1.000000       1.000000    1.000000    1.000000
#
#        DiabetsPedigreeFunction         Age
# count               768.000000  768.000000
# mean                  0.168179    0.204015
# std                   0.141473    0.196004
# min                   0.000000    0.000000
# 25%                   0.070773    0.050000
# 50%                   0.125747    0.133333
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
standard_scaled = mean_imputed.copy()

# %%
standard_scaled.iloc[:,1:8] = standard_scaler.fit_transform(standard_scaled.iloc[:,1:8])

# %%
standard_scaled.describe()
# Out:
#             Glucose  BloddPressure  SkinThickness       Insulin           BMI  \
# count  7.680000e+02   7.680000e+02   7.680000e+02  7.680000e+02  7.680000e+02
# mean  -3.301757e-16   6.966722e-16   6.866252e-16 -2.352033e-16  3.553292e-16
# std    1.000652e+00   1.000652e+00   1.000652e+00  1.000652e+00  1.000652e+00
# min   -2.554131e+00  -4.004245e+00  -2.521670e+00 -1.665945e+00 -2.075119e+00
# 25%   -7.212214e-01  -6.953060e-01  -4.727737e-01 -4.007289e-01 -7.215397e-01
# 50%   -1.540881e-01  -1.675912e-02   8.087936e-16 -3.345079e-16 -8.363615e-03
# 75%    6.103090e-01   6.282695e-01   3.240194e-01 -3.345079e-16  6.029301e-01
# max    2.541850e+00   4.102655e+00   7.950467e+00  8.126238e+00  5.042087e+00
#
#        DiabetsPedigreeFunction           Age
# count             7.680000e+02  7.680000e+02
# mean              2.398978e-16  1.857600e-16
# std               1.000652e+00  1.000652e+00
# min              -1.189553e+00 -1.041549e+00
# ...
