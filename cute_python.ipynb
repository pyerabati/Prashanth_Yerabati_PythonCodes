# %%
#Create a list of integers from 1 to 100. Using list comprehension, generate a list of
#squares of the above integers if they are odd.
[x**2 for x in range(1,100) if x%2==1]
# Out:
# [1,
#  9,
#  25,
#  49,
#  81,
#  121,
#  169,
#  225,
#  289,
#  361,
#  441,
#  529,
#  625,
#  729,
#  841,
#  961,
#  1089,
#  1225,
#  1369,
#  1521,
#  1681,
#  1849,
#  2025,
#  2209,
#  2401,
#  2601,
#  2809,
#  3025,
#  3249,
#  3481,
#  3721,
#  3969,
#  4225,
#  4489,
#  4761,
#  5041,
#  5329,
#  5625,
#  5929,
#  6241,
#  6561,
#  6889,
#  7225,
#  7569,
#  7921,
#  8281,
#  8649,
#  9025,
#  9409,
#  9801]

# %%
# Write a function that returns the number of vowels in a given string.
str=input("Enter string:")
vow=0
for i in str:
      if(i=='a' or i=='e' or i=='i' or i=='o' or i=='u' or i=='A' or i=='E' or i=='I' or i=='O' or i=='U'):
            vow=vow+1
print("Number of vowels are:")
print(vow)
# Out:
# Enter string:ravi shastri
# Number of vowels are:
# 4

# %%
import os
import pandas as pd
import numpy as np
os.getcwd()
# Out:
# 'D:\\Insofe\\Python Lab'

# %%
os.getcwd()
os.chdir("D:\\Insofe\\Python Lab")

# %%
bank = pd.read_csv("bank.csv",delimiter=';')

# %%
bank.shape
# Out:
# (4521, 17)

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null object
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# dtypes: int64(7), object(10)
# memory usage: 600.5+ KB

# %%
bank.head(6)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
# 5   35   management   single   tertiary      no      747      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
# ...

# %%
# What is the most common occupation in the ‘job’ column?
bank_mjob = bank["job"].value_counts()
bank_mjob.sort_values(ascending=False).head(1)
# Out:
# management    969
# Name: job, dtype: int64

# %%
#What is the mean ‘balance’ for people with marital status as married and also
#education as tertiary?
bankm =bank[(bank.marital == 'married') | (bank.education == 'tertiary')]['balance']
bankmean = bankm.mean()
bankmean
# Out:
# 1501.9406432748538

# %%
#What is the mean ‘age’ for different ‘education’ categories?
bank.groupby(by='education').aggregate({
    'age':'mean'
    
})
# Out:
#                  age
# education
# primary    46.833333
# secondary  40.062446
# tertiary   39.645926
# unknown    45.299465

# %%
#Drop the following columns from the dataframe:
#job, day, month, pdays, previous, poutcome.
bank_na_cols_dropped = bank.copy()
bank_na_cols_dropped.drop(['job','day','month','pdays','previous','poutcome'],axis=1)
# Out:
#       age   marital  education default  balance housing loan    contact  \
# 0      30   married    primary      no     1787      no   no   cellular
# 1      33   married  secondary      no     4789     yes  yes   cellular
# 2      35    single   tertiary      no     1350     yes   no   cellular
# 3      30   married   tertiary      no     1476     yes  yes    unknown
# 4      59   married  secondary      no        0     yes   no    unknown
# 5      35    single   tertiary      no      747      no   no   cellular
# 6      36   married   tertiary      no      307     yes   no   cellular
# 7      39   married  secondary      no      147     yes   no   cellular
# 8      41   married   tertiary      no      221     yes   no    unknown
# 9      43   married    primary      no      -88     yes  yes   cellular
# 10     39   married  secondary      no     9374     yes   no    unknown
# 11     43   married  secondary      no      264     yes   no   cellular
# ...

# %%
#Recode categorical variables with 2 levels as 0 & 1.
bank.info()
bank.marital = bank.martial.astype("category")
bank.info()
dummies = pd.get_dummies(bank['marital'])
bank = pd.concat([bank,dummies],axis=1)
bank.head(6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 20 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null category
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# divorced     4521 non-null uint8
# married      4521 non-null uint8
# single       4521 non-null uint8
# dtypes: category(1), int64(7), object(9), uint8(3)
# memory usage: 583.0+ KB
# ---------------------------------------------------------------------------
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null object
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# dtypes: int64(7), object(10)
# memory usage: 600.5+ KB

# %%
bank_data_dummy = pd.get_dummies(bank["marital"])
bank_data_dummy_merged = pd.concat([bank,bank_data_dummy],axis=1)
bank_data_dummy_merged = bank_data_dummy_merged.drop("marital",axis=1)
bank_data_dummy_merged.head(6)
# Out:
#    age          job  education default  balance housing loan   contact  day  \
# 0   30   unemployed    primary      no     1787      no   no  cellular   19
# 1   33     services  secondary      no     4789     yes  yes  cellular   11
# 2   35   management   tertiary      no     1350     yes   no  cellular   16
# 3   30   management   tertiary      no     1476     yes  yes   unknown    3
# 4   59  blue-collar  secondary      no        0     yes   no   unknown    5
# 5   35   management   tertiary      no      747      no   no  cellular   23
#
#   month   ...    pdays  previous  poutcome   y  divorced  married  single  \
# 0   oct   ...       -1         0   unknown  no         0        1       0
# 1   may   ...      339         4   failure  no         0        1       0
# 2   apr   ...      330         1   failure  no         0        0       1
# 3   jun   ...       -1         0   unknown  no         0        1       0
# ...

# %%
#Standardize the numeric columns.

from sklearn.preprocessing import Imputer
mean_imputer = Imputer(strategy="mean")

# %%
bank.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# divorced     0
# married      0
# single       0
# dtype: int64

# %%
mean_imputed = bank.copy()
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 20 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null category
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# divorced     4521 non-null uint8
# married      4521 non-null uint8
# single       4521 non-null uint8
# dtypes: category(1), int64(7), object(9), uint8(3)
# memory usage: 583.0+ KB

# %%
mean_imputed.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]] = mean_imputer.fit_transform(mean_imputed.mean_imputed.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]])

# %%
mean_imputed.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# divorced     0
# married      0
# single       0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
standard_scaled = mean_imputed.copy()

# %%
standard_scaled.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]] = standard_scaler.fit_transform(standard_scaled.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]])
# Out:
# C:\Users\Prashanth Yerabati\DS_Python\Anaconda\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-b52545b72e1b> in <module>()
# ----> 1 standard_scaled.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]] = standard_scaler.fit_transform(standard_scaled.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]])
#
# ~\DS_Python\Anaconda\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
# ...

# %%
standard_scaled.loc[:,["age","balance","day","duration","compaign","pdays","previous","divorced","married","single"]].isna().sum()
# Out:
# C:\Users\Prashanth Yerabati\DS_Python\Anaconda\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# age            0
# balance        0
# day            0
# duration       0
# compaign    4521
# pdays          0
# previous       0
# divorced       0
# married        0
# single         0
# dtype: int64
